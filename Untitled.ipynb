# %%
from datetime import datetime
import numpy as np
import pandas as pd
from pandas.api.types import CategoricalDtype

# %%
filepath = r"C:\Projects\jinan_dashboard\data\bus_data\new_bus_arrival_18051_2nd.csv"
df = pd.read_csv(filepath)

# %%
df
# Out:
#                             _id            date_time       date     time  \
# 0      601484c0ba47eff88ed6a8fd  2021-01-30 05:57:20  1/30/2021  57:20.3
# 1      601484fdba47eff88ed6a909  2021-01-30 05:58:21  1/30/2021  58:21.1
# 2      60148539ba47eff88ed6a915  2021-01-30 05:59:21  1/30/2021  59:21.9
# 3      60148576ba47eff88ed6a921  2021-01-30 06:00:22  1/30/2021  00:22.8
# 4      601485b3ba47eff88ed6a92d  2021-01-30 06:01:23  1/30/2021  01:23.7
# ...                         ...                  ...        ...      ...
# 21379  60421feff2309c1b985cf234  2021-03-05 20:11:27   3/5/2021  11:27.6
# 21380  6042202cf2309c1b985cf245  2021-03-05 20:12:28   3/5/2021  12:28.3
# 21381  60422069f2309c1b985cf256  2021-03-05 20:13:29   3/5/2021  13:29.1
# 21382  604220a6f2309c1b985cf267  2021-03-05 20:14:30   3/5/2021  14:30.2
# 21383  604220e3f2309c1b985cf279  2021-03-05 20:15:31   3/5/2021  15:32.0
#
#        bus_number operator first_next_bus_estimated_arrival  \
# ...

# %%
df["date"] = pd.to_datetime(df["date"], format="%m/%d/%Y")

# %%
cats = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
cat_type = CategoricalDtype(categories=cats, ordered=True)
df["Weekday"] = df["date"].dt.day_name()
df['Weekday']=df['Weekday'].astype(cat_type)

# %%
test = df.groupby(["Weekday", "Hour"], as_index=False).mean()

# %%
test[["Weekday", "Hour", "Late_By"]].head(40)
# Out:
#       Weekday  Hour     Late_By
# 0      Monday     5         NaN
# 1      Monday     6  104.900000
# 2      Monday     7  214.611111
# 3      Monday     8  202.080000
# 4      Monday     9  180.809524
# 5      Monday    10  134.176471
# 6      Monday    11  152.466667
# 7      Monday    12  164.357143
# 8      Monday    13  158.384615
# 9      Monday    14  106.470588
# 10     Monday    15  106.000000
# 11     Monday    16  160.411765
# 12     Monday    17  192.550000
# 13     Monday    18  179.347826
# 14     Monday    19  135.857143
# 15     Monday    20  102.375000
# 16    Tuesday     5         NaN
# 17    Tuesday     6  109.125000
# 18    Tuesday     7  167.875000
# 19    Tuesday     8  155.636364
# 20    Tuesday     9  199.142857
# 21    Tuesday    10   81.000000
# 22    Tuesday    11  123.153846
# 23    Tuesday    12  193.111111
# 24    Tuesday    13  178.285714
# 25    Tuesday    14  129.727273
# 26    Tuesday    15  100.928571
# 27    Tuesday    16   97.692308
# ...

# %%
test1 = df.groupby(["Weekday", "Hour", "Late_By"], as_index=False).mean()
test1.head(10)
# Out:
#   Weekday  Hour  Late_By  bus_number  first_next_bus_origin_code  \
# 0  Monday     5      1.0         NaN                         NaN
# 1  Monday     5      2.0         NaN                         NaN
# 2  Monday     5      3.0         NaN                         NaN
# 3  Monday     5      4.0         NaN                         NaN
# 4  Monday     5      5.0         NaN                         NaN
# 5  Monday     5      6.0         NaN                         NaN
# 6  Monday     5      7.0         NaN                         NaN
# 7  Monday     5      8.0         NaN                         NaN
# 8  Monday     5      9.0         NaN                         NaN
# 9  Monday     5     10.0         NaN                         NaN
#
#    first_next_bus_destination_code  first_next_bus_visit_number  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# ...
